# %%
# %pylab inline
import matplotlib.pyplot as plt
from scipy import interpolate

plt.title('Slices comparison')
plt.ylabel('slices on implementation')
plt.xlabel('Bits')

x_shift = [2, 3,  4,   6,  8,12,16,24,32,48,64,96]
y_shift = [2, 3,  6,  15, 27,62,116,269,485,1111,1987,4515]

x_3 =     [3,6,12,24,48,96]
y_3 =     [3,17,63,217,717,2298]

x_5 =     [5,10,20,40,80]
y_5 =     [11,46,169,570,1851]

x_2_Xor =  [2,4,8,16,32,64]
y_2_Xor =  [2,8,40,124,438,1475]

f_2_Xor = interpolate.UnivariateSpline(x_2_Xor,y_2_Xor)
x_2_new_Xor = range(100)
y_2_new_Xor=f_2_Xor(x_2_new_Xor)


f_3 = interpolate.UnivariateSpline(x_3,y_3)
x_3_new = range(100)
y_3_new=f_3(x_3_new)

f_shift = interpolate.UnivariateSpline(x_shift,y_shift)
x_shift_new = range(100)
y_shift_new=f_shift(x_shift_new)

f_5 = interpolate.UnivariateSpline(x_5,y_5)
x_5_new = range(100)
y_5_new=f_5(x_5_new)

plt.plot(x_2_new_Xor, y_2_new_Xor, '-x', x_3_new,y_3_new,'-x',x_shift_new,y_shift_new,'-x', x_5_new,y_5_new,'-x', x_3, y_3, 'o', x_shift, y_shift, 'o')
plt.legend(['mul_2','mul_3', 'mul_shift','mul_5'], loc='best')
xlim(0, 15)
ylim(0, 100)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt
from scipy import interpolate

plt.title('Slices comparison')
plt.ylabel('slices on implementation')
plt.xlabel('Bits')


x_3 =     [3,6,12,24,48,96]
y_3 =     [3,17,63,217,717,2298]



x_3_shift  =     [3,6,12,24,48,96]
y_3_shift  =     [3,15,54,194,656,2134]


x_5 =     [5,10,20,40,80]
y_5 =     [10,40,154,5,1746]

x_5_shift = [5,10,20,40,80]
y_5_shift =     [10,38,142,493,1609]

f_3 = interpolate.UnivariateSpline(x_3,y_3)
x_3_new = range(100)
y_3_new=f_3(x_3_new)

f_3_shift  = interpolate.UnivariateSpline(x_3_shift ,y_3_shift )
x_3_new_shift  = range(100)
y_3_new_shift =f_3_shift (x_3_new_shift)

f_5 = interpolate.UnivariateSpline(x_5,y_5)
x_5_new = range(100)
y_5_new=f_5(x_5_new)

f_5_shift = interpolate.UnivariateSpline(x_5_shift,y_5_shift)
x_5_new_shift = range(100)
y_5_new_shift=f_5_shift(x_5_new_shift)


plt.plot( x_3_new,y_3_new,'-x', x_5_new,y_5_new,'-x', x_5_new_shift,y_5_new_shift,'-x',x_3_new_shift,y_3_new_shift,'-x')
plt.legend(['mul_3', 'mul_5','mul_5_shift','mul_3_Shift'], loc='best')
xlim(0, 100)
ylim(0, 2000)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
fftlength = 1000
plot(abs(rfft(column_stack((
  [2, 2  ],
  [4, 8],
  [8, 41],
  [16, 140],
  [32, 466],
  [64, 1535])), fftlength, axis=0)))
ylim(0, 2000)
show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt
from scipy import interpolate

plt.title('Slices comparison')
plt.ylabel('slices on implementation')
plt.xlabel('Bits')


x_5=     [4,8,16,32,64]
y_5 =     [6,24,109,360,1201]

x_3 =     [6,12,24,48,96]
y_3 =     [15,54,194,656,2134]


f_2 = interpolate.UnivariateSpline(x_5,y_5)
x_2_new = range(100)
y_2_new=f_2(x_2_new)

f_3 = interpolate.UnivariateSpline(x_3,y_3)
x_3_new = range(100)
y_3_new=f_3(x_3_new)



plt.plot(x_2_new, y_2_new , '-x', x_3_new,y_3_new,'-x',x_5, y_5, 'o', x_3, y_3, 'o')
plt.legend(['mul_64','mul_96'], loc='best')
xlim(0, 100)
ylim(0, 2000)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
